# %%
import yfinance as yf

# %%
ticker = "^DJI" #"MSFT"
dat = yf.Ticker(ticker)

# %%
dat.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 40227.59,
#  'open': 40234.0,
#  'dayLow': 40222.18,
#  'dayHigh': 40630.49,
#  'regularMarketPreviousClose': 40227.59,
#  'regularMarketOpen': 40234.0,
#  'regularMarketDayLow': 40222.18,
#  'regularMarketDayHigh': 40630.49,
#  'volume': 430031312,
#  'regularMarketVolume': 430031312,
#  'averageVolume': 669735081,
#  'averageVolume10days': 601452000,
#  'averageDailyVolume10Day': 601452000,
#  'bid': 40399.64,
#  'ask': 40693.95,
#  'bidSize': 0,
#  'askSize': 0,
#  'fiftyTwoWeekLow': 36611.78,
#  'fiftyTwoWeekHigh': 45073.63,
#  'fiftyDayAverage': 41581.42,
#  'twoHundredDayAverage': 42210.406,
#  'currency': 'USD',
#  'tradeable': False,
#  '52WeekChange': 6.377399,
#  'quoteType': 'INDEX',
#  'symbol': '^DJI',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Index',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'regularMarketChange': 300.03125,
#  'regularMarketDayRange': '40222.18 - 40630.49',
#  'fullExchangeName': 'DJI',
#  'averageDailyVolume3Month': 669735081,
#  'fiftyTwoWeekLowChange': 3915.8398,
#  'fiftyTwoWeekLowChangePercent': 0.10695573,
#  'fiftyTwoWeekRange': '36611.78 - 45073.63',
#  'fiftyTwoWeekHighChange': -4546.008,
#  'fiftyTwoWeekHighChangePercent': -0.10085737,
#  'fiftyTwoWeekChangePercent': 6.377399,
#  'shortName': 'Dow Jones Industrial Average',
#  'longName': 'Dow Jones Industrial Average',
#  'regularMarketChangePercent': 0.7458345,
#  'regularMarketPrice': 40527.62,
#  'fiftyDayAverageChange': -1053.8008,
#  'fiftyDayAverageChangePercent': -0.025343068,
#  'twoHundredDayAverageChange': -1682.7852,
#  'twoHundredDayAverageChangePercent': -0.039866596,
#  'sourceInterval': 120,
#  'exchangeDataDelayedBy': 0,
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 694362600000,
#  'marketState': 'POST',
#  'corporateActions': [],
#  'regularMarketTime': 1745958000,
#  'exchange': 'DJI',
#  'messageBoardId': 'finmb_INDEXDJI',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'trailingPegRatio': None}

# %%
dat.calendar
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EDJI?modules=calendarEvents&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EDJI&crumb=HZPV98l8eai
# {}

# %%
dat.analyst_price_targets
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EDJI?modules=financialData&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EDJI&crumb=HZPV98l8eai
# {}

# %%
dat.quarterly_income_stmt
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dat.history(period='max')
# Out:
#                                    Open          High           Low  \
# Date
# 1992-01-02 00:00:00-05:00   3152.100098   3172.629883   3139.310059
# 1992-01-03 00:00:00-05:00   3172.399902   3210.639893   3165.919922
# 1992-01-06 00:00:00-05:00   3201.500000   3213.330078   3191.860107
# 1992-01-07 00:00:00-05:00   3200.100098   3210.199951   3184.479980
# 1992-01-08 00:00:00-05:00   3204.800049   3229.199951   3185.820068
